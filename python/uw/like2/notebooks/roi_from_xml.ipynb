# %% [markdown]
# #Create an ROI from an XML file
# Here use the one generated by the unit tests, which was generated from a like2 healpix-based ROI

# %%
import os
tmpdir = '/tmp/like2'
xml_file = 'ROI_0840.xml'
if not os.path.exists(tmpdir): os.makedirs(tmpdir)
os.chdir(tmpdir)
with open('config.txt', 'w') as f:
    f.write(
"""{
    'dataspec': dict(data_name='P7 reprocessed data, 4 years, flares removed',
                 ft1files =  None,  
                 ft2files = None, 
                 binsperdec=4,
                 binfile = 'P7_P202/4years_4bpd.fits',
                 ltcube =  'P7_P202/ltcube_4years_zmax100.fits',
        ),
    
    'irf': 'P7REP_SOURCE_V15',
    
    'input_model' : dict(
        xml_file="%(xml_file)s",
    ),

    'diffuse': dict(
        ring    =  dict(filename='template_4years_P7_v15_repro_v3_4bpd.zip',
                    correction='galactic_correction_v3.csv', 
                    systematic=0.0316), 
        isotrop = '4Y_SOURCE_**_V9_EGBfree.txt', #4Y_SOURCE_**_v9_EGBfree.txt',
        SunMoon = 'SunMoon_4years_zmax100.fits', 
        limb    = 'AziLimb:azi_limb_P7_v0_*.txt',
        ),
    
    'extended': 'Extended_archive_v14',
}""" % dict(xml_file=xml_file)
)
assert os.path.exists(xml_file), 'File %s not found' % xml_file
# %matplotlib inline

# %%
from uw.like2 import main, extended, configuration, dataset; 
map(reload,         (main, extended, configuration, dataset,))
config = configuration.Configuration('.'); config
# Out:
# Using configuration file "config.txt" in folder: /tmp/like2/.
# Extracting DSS from existing binfile
# GTI from binfile
#  Gti: 22858 intervals from 239557417 to 365467549, on time 102630509
# Verified binfile /phys/users/tburnett/fermi/data/P7_P202/4years_4bpd.fits
# no header info in ltcube?
# Accepting ltcube without DSS info since legacy specified
# Verified ltcube /phys/users/tburnett/fermi/data/P7_P202/ltcube_4years_zmax100.fits
# loading binfile /phys/users/tburnett/fermi/data/P7_P202/4years_4bpd.fits ...
#  found 71168552 photons in 40 bands, energies 10-1000000 MeV
# dataset "P7 reprocessed data, 4 years, flares removed", found in config.txt:
#   Bins per decade: 4
#   FT1 files: 	None
#   FT2 files: 	None
#   Binned data: /phys/users/tburnett/fermi/data/P7_P202/4years_4bpd.fits
#              :  71168552 photons, 40 energy bands from 10 to 1000000 MeV
#   Livetime cube: /phys/users/tburnett/fermi/data/P7_P202/ltcube_4years_zmax100.fits
#   Gti: 22858 intervals from 239557417 to 365467549, on time 102630509
#   DSS: name             value     units     ref
#        TIME             TABLE     s          :GTI
#        ENERGY           30:1000000MeV        None
#        ZENITH_ANGLE     0:100     deg        None
#        THETA            :66.4     deg        None
#        BIT_MASK(EVENT_CLASS,2)  1:1       DIMENSIONLESS None
#
# will load sources from  file ROI_0840.xml
# uw.like2.configuration.Configuration: /tmp/like2/.

# %%
roi = main.ROI('.'); roi
# Out:
# uw.like2.main.ROI :
# 	uw.like2.configuration.Configuration: /tmp/like2/.
# 	uw.like2.from_xml.ROImodelFromXML: file ROI_0840.xml

# %%
roi.summarize()
# Out:
# current likelihood, est. diff to peak: 693096.4, 45.62
# Name                  index     value  error(%)  gradient
# isotrop_Scale             0       1.6       3.8     -65.0
# P7R42722_Norm             1 5.348e-12       6.0     -89.4
#         _Index            2      1.88       4.4     -48.1
#         _beta             3    0.6879      11.6      56.6
# P7R42734_Norm             4  6.13e-13       9.1      -4.7
#         _Index            5     2.486       6.2      -6.0
#         _beta             6    0.8862      17.4      10.2
# P7R42730_Norm             7 6.585e-12       5.0      27.4
#         _Index            8     2.107       3.1       1.3
#         _beta             9    0.3375      16.0     -11.4
# P7R42773H_Norm           10 1.064e-13      21.9      -9.1
#          _Index          11     2.318       6.1      -6.3
# P7R42728_Norm            12 1.263e-11       6.7    -230.6
#         _Index           13     2.601       1.8     -78.8
#         _beta            14    0.2599      11.5      62.2
# P7R42712H_Norm           15  1.21e-12      15.3      -9.1
#          _Index          16     2.739       3.4      -4.0
# P7R42767_Norm            17 4.189e-13       8.2     -12.2
#         _Index           18     2.528       5.6     -14.8
#         _beta            19    0.4167      18.2      45.0
# PSR J1801-2451_Norm      20  4.23e-14      52.9      -2.1
#               _Index     21      1.31      28.3      -2.3
#               _Cutoff    22 1.665e+04      65.7       0.6
# P7R42760_Norm            23 4.506e-14      21.4     -13.4
#         _Index           24     1.947       5.3     -17.6
# P7R42747_Norm            25 1.291e-12       9.5       7.8
#         _Index           26     1.927       6.3      -0.7
#         _beta            27    0.5353      20.1       0.7
# P7R42712P_Norm           28 4.434e-14      32.9      -6.1
#          _Index          29     2.019       8.9      -6.1
# P7R42758_Norm            30 6.085e-14      19.1     -18.6
#         _Index           31     1.937       4.8     -21.5
# W28_Norm                 32  3.28e-11       2.1     -21.2
#    _Index                33     2.283       0.6    -142.9
#    _beta                 34   0.09384       9.8    -185.7

# %%
roi.fit()
# Out:
# 23 calls, function value, improvement, quality: 693140.1, 43.63, 0.94
# Name                  index     value  error(%)  gradient
# isotrop_Scale             0     1.788      11.3       5.6
# P7R42722_Norm             1 5.088e-12       8.4       3.6
#         _Index            2     2.273       4.2      -0.2
#         _beta             3    0.3149      28.9      -5.3
# P7R42734_Norm             4 6.165e-13      13.5      -3.1
#         _Index            5     2.449       9.2      -1.3
#         _beta             6    0.9293      27.8       1.1
# P7R42730_Norm             7 6.487e-12       7.2       3.4
#         _Index            8     2.016       6.3      -1.0
#         _beta             9    0.4023      24.2      -0.2
# P7R42773H_Norm           10 1.178e-13      28.6      -0.9
#          _Index          11     2.398       9.1      -1.1
# P7R42728_Norm            12 1.262e-11      10.8       0.5
#         _Index           13     2.603       4.4       7.0
#         _beta            14    0.2987      28.8      -4.9
# P7R42712H_Norm           15  1.28e-12      22.4      -2.2
#          _Index          16     2.766       6.7      -0.8
# P7R42767_Norm            17 3.822e-13      12.1       4.0
#         _Index           18     2.415       6.6       6.0
#         _beta            19    0.2275      46.2      -2.4
# PSR J1801-2451_Norm      20 4.467e-14      76.9      -0.4
#               _Index     21     1.354      47.8      -0.5
#               _Cutoff    22  1.59e+04     101.7       0.0
# P7R42760_Norm            23 4.435e-14      31.0      -4.2
#         _Index           24     2.077       8.9       0.1
# P7R42747_Norm            25 1.243e-12      13.6      -0.9
#         _Index           26     1.923       9.7       0.2
#         _beta            27    0.5196      31.8       0.1
# P7R42712P_Norm           28 5.658e-14      41.7      -1.6
#          _Index          29     2.151      13.5      -3.9
# P7R42758_Norm            30 6.844e-14      25.0      -6.4
#         _Index           31     2.125       7.3      -0.2
# W28_Norm                 32  3.28e-11       3.3      -0.5
#    _Index                33     2.291       1.4       4.3
#    _beta                 34    0.1289      16.6      -3.4
