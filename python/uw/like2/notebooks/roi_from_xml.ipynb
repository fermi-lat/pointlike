# %% [markdown]
# #Create an ROI from an XML file
# Here use the one generated by the unit tests, which was generated from a like2 healpix-based ROI

# %%
# %matplotlib inline
os.chdir(os.path.expandvars('$FERMI/test_like2'))
from uw.like2 import main, extended, configuration, dataset,from_xml, from_healpix, bands; 
map(reload,         (main, extended, configuration, dataset,from_xml, from_healpix, bands));
#%time config = configuration.Configuration('.', quiet=False); config
# Out:
# [<module 'uw.like2.main' from '/phys/users/tburnett/python/uw/like2/main.pyc'>,
#  <module 'uw.like2.extended' from '/phys/users/tburnett/python/uw/like2/extended.pyc'>,
#  <module 'uw.like2.configuration' from '/phys/users/tburnett/python/uw/like2/configuration.pyc'>,
#  <module 'uw.like2.dataset' from '/phys/users/tburnett/python/uw/like2/dataset.pyc'>,
#  <module 'uw.like2.from_xml' from '/phys/users/tburnett/python/uw/like2/from_xml.pyc'>,
#  <module 'uw.like2.from_healpix' from '/phys/users/tburnett/python/uw/like2/from_healpix.pyc'>,
#  <module 'uw.like2.bands' from '/phys/users/tburnett/python/uw/like2/bands.pyc'>]

# %%
# %time self= main.ROI('.')
# Out:
# WARNING: there are no free parameters
# 142 total sources: 0 extended, 0 global
# CPU times: user 1min 34s, sys: 465 ms, total: 1min 34s
# Wall time: 1min 35s

# %%
self.print_summary()
# Out:
# ------------------------------------------------------------------------------------------
# 	 Nearby sources within 5.0 degrees ROI(266.390,-28.931, 10.0)
# name               dist        ra       dec        TS eflux(eV)    index   energy   beta/b
# P7R42735            0.1   266.413   -28.987                66.3     2.67    19125     0.25
# P7R42717            0.1   266.350   -29.057               161.8     1.73      885     0.49
# P7R42722            0.2   266.602   -28.860                77.0     2.09     2388     0.50
# P7R42737A           0.5   266.943   -29.075               114.1     2.73     1150     0
# P7R42728            0.6   266.775   -28.482                87.2     2.57     1397     0.44
# SgrC                0.6   266.100   -29.440                14.5     0.99     1810     1.69
# P7R42738G           0.9   267.332   -29.198                36.4     2.47     3138     0
# P7R42734            0.9   267.094   -28.255                25.4     2.39     4677     0.93
# ...
